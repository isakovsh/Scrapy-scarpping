# %%
import pandas as pd
import re
from bs4 import BeautifulSoup
import requests

# %%
df=pd.read_csv("url_data.csv")
df.head()
# Out:
#        section_info                                      question_text  \
# 0  Dolzarb savollar  Assalomu alaykum! Faqir miskinlar deb kimlar a...
# 1    Turli savollar  Assalomu alaykum! Uy oldi sotdi o'rtasidagi ya...
# 2         Ibodatlar  Assalomu alaykum! Sahf sajdasi qanday oqiladi?...
# 3         Ibodatlar  Assalomu alaykum! Hurmatli ustozlar, agar bir ...
# 4    Turli savollar  Assalomu alaykum!Bir savolim bor edi.Tavba yo'...
#
#                                          answer_text  views_info        date  \
# 0  Va alaykum assalom!Moli nisobga etmagan kishil...        2264  09.03.2017
# 1  – Va alaykum assalom! Quyidagi linkda berilgan...        1314  06.07.2020
# 2  Va alaykum assalom!http://fiqh.uz/index.php/ib...        1961  12.03.2017
# 3  Va alaykum assalom!http://savollar.islom.uz/sm...        2308  13.03.2017
# 4  Va alaykum assalom!http://old.islom.uz/content...        1994  13.03.2017
#
#                                                link1
# ...

# %%
def to_check_url(url):
    response=requests.get(url=url)
    if response=='<Response [200]>':
        return True
    else: return False

# %%
df['checked_url']=df['link1'][:1000].apply(to_check_url)
# Out:
# ---------------------------------------------------------------------------
# ConnectionAbortedError                    Traceback (most recent call last)
# File c:\Users\acer\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File c:\Users\acer\AppData\Local\Programs\Python\Python310\lib\site-packages\urllib3\util\connection.py:85, in create_connection(address, timeout, source_address, socket_options)
# ...

# %%
# Out:
#           section_info                                      question_text  \
# 0     Dolzarb savollar  Assalomu alaykum! Faqir miskinlar deb kimlar a...
# 1       Turli savollar  Assalomu alaykum! Uy oldi sotdi o'rtasidagi ya...
# 2            Ibodatlar  Assalomu alaykum! Sahf sajdasi qanday oqiladi?...
# 3            Ibodatlar  Assalomu alaykum! Hurmatli ustozlar, agar bir ...
# 4       Turli savollar  Assalomu alaykum!Bir savolim bor edi.Tavba yo'...
# ...                ...                                                ...
# 3430  Dolzarb savollar  Shayx Muhammad Sodiq Muhammad Yusuf hazratlari...
# 3431  Dolzarb savollar  Shayx Muhammad Sodiq Muhammad Yusuf hazratlari...
# 3432  Boshqa ibodatlar  Assalomu alaykum SHayx xazratlari savolimiz qu...
# 3433   Siyrat va tarix  Assalomu alaykum Shayx hazratlari. Men tarixga...
# 3434             Namoz  Assalomu alaykum shayh hazratlari bir masalani...
#
#                                             answer_text  views_info  \
# ...
